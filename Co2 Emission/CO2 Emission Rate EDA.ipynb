# %%
# Importing Libraries :

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots

# %%
# Reading the DataFrame :

EHG_df = pd.read_csv("C:/Users/viraj/Dropbox/PC (2)/Downloads/Co2emissions Eda/emissions_high_granularity.csv")

# %%
# Showing the DataFrame :

EHG_df
# Out:
#        year                   parent_entity         parent_type  \
# 0      1962  Abu Dhabi National Oil Company  State-owned Entity
# 1      1963  Abu Dhabi National Oil Company  State-owned Entity
# 2      1964  Abu Dhabi National Oil Company  State-owned Entity
# 3      1965  Abu Dhabi National Oil Company  State-owned Entity
# 4      1966  Abu Dhabi National Oil Company  State-owned Entity
# ...     ...                             ...                 ...
# 15792  2020                             YPF  State-owned Entity
# 15793  2021                             YPF  State-owned Entity
# 15794  2021                             YPF  State-owned Entity
# 15795  2022                             YPF  State-owned Entity
# 15796  2022                             YPF  State-owned Entity
#
#       reporting_entity    commodity  production_value production_unit  \
# 0            Abu Dhabi    Oil & NGL            0.9125  Million bbl/yr
# ...

# %%
# First 5 Rows of DataFrame :

EHG_df.head()
# Out:
#    year                   parent_entity         parent_type reporting_entity  \
# 0  1962  Abu Dhabi National Oil Company  State-owned Entity        Abu Dhabi
# 1  1963  Abu Dhabi National Oil Company  State-owned Entity        Abu Dhabi
# 2  1964  Abu Dhabi National Oil Company  State-owned Entity        Abu Dhabi
# 3  1965  Abu Dhabi National Oil Company  State-owned Entity        Abu Dhabi
# 4  1966  Abu Dhabi National Oil Company  State-owned Entity        Abu Dhabi
#
#    commodity  production_value production_unit  product_emissions_MtCO2  \
# 0  Oil & NGL            0.9125  Million bbl/yr                 0.338928
# 1  Oil & NGL            1.8250  Million bbl/yr                 0.677855
# 2  Oil & NGL            7.3000  Million bbl/yr                 2.711422
# 3  Oil & NGL           10.9500  Million bbl/yr                 4.067132
# 4  Oil & NGL           13.5050  Million bbl/yr                 5.016130
#
#    flaring_emissions_MtCO2  venting_emissions_MtCO2  \
# ...

# %%
# DataFrame Summary Information :

EHG_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15797 entries, 0 to 15796
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   year                                15797 non-null  int64
#  1   parent_entity                       15797 non-null  object
#  2   parent_type                         15797 non-null  object
#  3   reporting_entity                    15797 non-null  object
#  4   commodity                           15797 non-null  object
#  5   production_value                    15797 non-null  float64
#  6   production_unit                     15797 non-null  object
#  7   product_emissions_MtCO2             15797 non-null  float64
#  8   flaring_emissions_MtCO2             15797 non-null  float64
#  9   venting_emissions_MtCO2             15797 non-null  float64
#  10  own_fuel_use_emissions_MtCO2        15797 non-null  float64
# ...

# %%
# DataFrame Summary Statistics of Numeric Columns :

EHG_df.describe()
# Out:
#                year  production_value  product_emissions_MtCO2  \
# count  15797.000000      15797.000000             15797.000000
# mean    1985.827942        327.907296                79.401788
# std       28.664256       1188.655608               262.004900
# min     1854.000000          0.000000                 0.000000
# 25%     1970.000000         11.800000                 5.996490
# 50%     1993.000000         59.970871                21.502409
# 75%     2007.000000        246.375000                62.191954
# max     2022.000000      27192.000000              7769.222235
#
#        flaring_emissions_MtCO2  venting_emissions_MtCO2  \
# count             15797.000000             15797.000000
# mean                  0.517390                 0.462501
# std                   1.784590                 1.804616
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.015913                 0.045247
# ...

# %%
# DataFrame column labels :

EHG_df.columns
# Out:
# Index(['year', 'parent_entity', 'parent_type', 'reporting_entity', 'commodity',
#        'production_value', 'production_unit', 'product_emissions_MtCO2',
#        'flaring_emissions_MtCO2', 'venting_emissions_MtCO2',
#        'own_fuel_use_emissions_MtCO2', 'fugitive_methane_emissions_MtCO2e',
#        'fugitive_methane_emissions_MtCH4',
#        'total_operational_emissions_MtCO2e', 'total_emissions_MtCO2e',
#        'source'],
#       dtype='object')

# %%
# Data Types of Columns in CO2 Emission Dataset :

EHG_df.dtypes
# Out:
# year                                    int64
# parent_entity                          object
# parent_type                            object
# reporting_entity                       object
# commodity                              object
# production_value                      float64
# production_unit                        object
# product_emissions_MtCO2               float64
# flaring_emissions_MtCO2               float64
# venting_emissions_MtCO2               float64
# own_fuel_use_emissions_MtCO2          float64
# fugitive_methane_emissions_MtCO2e     float64
# fugitive_methane_emissions_MtCH4      float64
# total_operational_emissions_MtCO2e    float64
# total_emissions_MtCO2e                float64
# source                                 object
# dtype: object

# %%
# Unique Values in Categorical Columns :

categorical_columns = EHG_df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f'{col}: {EHG_df[col].unique()}')
# Out:
# parent_entity: ['Abu Dhabi National Oil Company' 'Adani Enterprises' 'Adaro Energy'
#  'Alliance Resource Partners' 'Alpha Metallurgical Resources'
#  'American Consolidated Natural Resources' 'Anglo American' 'Antero'
#  'APA Corporation' 'Arch Resources' 'Banpu' 'Bapco Energies' 'BASF' 'BHP'
#  'BP' 'British Coal Corporation' 'Bumi Resources'
#  'Canadian Natural Resources' 'Cemex' 'Cenovus Energy' 'Chesapeake Energy'
#  'Chevron' 'China (Cement)' 'China (Coal)' 'Cloud Peak' 'CNOOC' 'CNPC'
#  'CNX Resources' 'Coal India' 'ConocoPhillips' 'CONSOL Energy'
#  'Continental Resources' 'Coterra Energy' 'CRH' 'Cyprus AMAX Minerals'
#  'Czech Republic' 'Czechoslovakia' 'Devon Energy' 'Ecopetrol'
#  'Egyptian General Petroleum' 'Eni' 'EOG Resources' 'EQT Corporation'
#  'Equinor' 'Exxaro Resources Ltd' 'ExxonMobil' 'Former Soviet Union'
#  'Gazprom' 'Glencore' 'Heidelberg Materials' 'Hess Corporation'
#  'Holcim Group' 'Inpex' 'Iraq National Oil Company' 'Kazakhstan'
# ...

# %%
# Columns with Missing Values :

nan_values = EHG_df.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# year                                  False
# parent_entity                         False
# parent_type                           False
# reporting_entity                      False
# commodity                             False
# production_value                      False
# production_unit                       False
# product_emissions_MtCO2               False
# flaring_emissions_MtCO2               False
# venting_emissions_MtCO2               False
# own_fuel_use_emissions_MtCO2          False
# fugitive_methane_emissions_MtCO2e     False
# fugitive_methane_emissions_MtCH4      False
# total_operational_emissions_MtCO2e    False
# total_emissions_MtCO2e                False
# source                                False
# dtype: bool

# %%
# Count of Missing Values in Each Column :

EHG_df.isnull().sum()
# Out:
# year                                  0
# parent_entity                         0
# parent_type                           0
# reporting_entity                      0
# commodity                             0
# production_value                      0
# production_unit                       0
# product_emissions_MtCO2               0
# flaring_emissions_MtCO2               0
# venting_emissions_MtCO2               0
# own_fuel_use_emissions_MtCO2          0
# fugitive_methane_emissions_MtCO2e     0
# fugitive_methane_emissions_MtCH4      0
# total_operational_emissions_MtCO2e    0
# total_emissions_MtCO2e                0
# source                                0
# dtype: int64

# %% [markdown]
# ## Visualization of the DataFrame :

# %%
# 1. CO2 Emissions by Year :

plt.figure(figsize=(10, 6))
plt.bar(EHG_df['year'], EHG_df['total_emissions_MtCO2e'], color='skyblue')
plt.title('CO2 Emissions by Year')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (in metric tons)')
plt.xticks(EHG_df['year'])
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# 2. Distribution of Years :

plt.figure(figsize=(10, 6))
sns.countplot(data=EHG_df, x='year')
plt.title('Distribution of Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# 3. Bar Plot and Line Plot Subplots (Comparing different categories and trends over time) :


fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))

# Bar Plot
axes[0].bar(EHG_df['parent_entity'], EHG_df['total_emissions_MtCO2e'])
axes[0].set_xlabel('Parent Entity')
axes[0].set_ylabel('Total Emissions (MtCO2e)')
axes[0].set_title('Total Emissions by Parent Entity')

# Line Plot
axes[1].plot(EHG_df['year'], EHG_df['total_emissions_MtCO2e'], marker='o', linestyle='-')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Total Emissions (MtCO2e)')
axes[1].set_title('Total CO2 Emissions Over Time')

plt.tight_layout()
plt.show()

# %%
# 4. Scatter Plot Matrix (Exploring relationships between multiple variables) :

# Selecting relevant numeric columns for the scatter plot matrix
numeric_colm = ['production_value', 'product_emissions_MtCO2', 'flaring_emissions_MtCO2', 
                'venting_emissions_MtCO2', 'own_fuel_use_emissions_MtCO2', 
                'fugitive_methane_emissions_MtCO2e', 'fugitive_methane_emissions_MtCH4', 
                'total_operational_emissions_MtCO2e', 'total_emissions_MtCO2e']

# Creating a pairplot
sns.pairplot(EHG_df[numeric_colm])
plt.suptitle('Pairplot of Numeric Variables', y=1.02)
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# 5. Total Emissions by Commodity :

plt.figure(figsize=(10, 6))
sns.boxplot(x='commodity', y='total_emissions_MtCO2e', data=EHG_df)
plt.xlabel('Commodity')
plt.ylabel('Total Emissions (MtCO2e)')
plt.title('Total Emissions by Commodity')
plt.xticks(rotation=45)
plt.show()

# %%
# 6. Total CO2 Emissions Over Time :

plt.figure(figsize=(10, 6))
plt.plot(EHG_df['year'], EHG_df['total_emissions_MtCO2e'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Total Emissions (MtCO2e)')
plt.title('Total CO2 Emissions Over Time')
plt.grid(True)
plt.show()

# %%
# 7. Production Value by Commodity :

plt.figure(figsize=(10, 6))
plt.bar(EHG_df['commodity'], EHG_df['production_value'])
plt.xlabel('Commodity')
plt.ylabel('Production Value')
plt.title('Production Value by Commodity')
plt.xticks(rotation=45)
plt.show()

# %%
# 8. Scatter Plot of Production Value vs Total Emissions :

plt.figure(figsize=(10, 6))
plt.scatter(EHG_df['production_value'], EHG_df['total_emissions_MtCO2e'])
plt.xlabel('Production Value')
plt.ylabel('Total Emissions (MtCO2e)')
plt.title('Production Value vs Total Emissions')
plt.grid(True)
plt.show()

# %%
# 9. Distribution of Total CO2 Emissions :

plt.figure(figsize=(10, 6))
plt.hist(EHG_df['total_emissions_MtCO2e'], bins=20, color='skyblue')
plt.xlabel('Total Emissions (MtCO2e)')
plt.ylabel('Frequency')
plt.title('Distribution of Total Emissions')
plt.grid(True)
plt.show()

# %%
# 10.Total Emissions Distribution by Parent Type :

plt.figure(figsize=(10, 6))
sns.boxplot(x='parent_type', y='total_emissions_MtCO2e', data=EHG_df)
plt.xlabel('Parent Type')
plt.ylabel('Total Emissions (MtCO2e)')
plt.title('Total Emissions Distribution by Parent Type')
plt.show()

# %%
# 11. Proportion of Total Emissions by Parent Entity :

plt.figure(figsize=(8, 8))
plt.pie(EHG_df.groupby('parent_entity')['total_emissions_MtCO2e'].sum(), labels=EHG_df['parent_entity'].unique(), autopct='%1.1f%%')
plt.title('Total Emissions by Parent Entity')
plt.show()

# %%
# 12. Correlation Matrix of Numeric Variables :

# Select only numeric columns for correlation calculation
numeric_df = EHG_df.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(10, 8))
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# 13.Distribution of Parent Entity Counts :

plt.figure(figsize=(10, 6))
sns.countplot(data=EHG_df, y='parent_entity', order=EHG_df['parent_entity'].value_counts().index)
plt.title('Distribution of Parent Entity')
plt.xlabel('Count')
plt.ylabel('Parent Entity')
plt.show()

# %%
# 14. Proportion of Parent Entity Distribution :

plt.figure(figsize=(10, 6))
EHG_df['parent_entity'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Parent Entity')
plt.ylabel('')
plt.show()

# %%
# 15. Distribution of Parent Types :

plt.figure(figsize=(10, 6))
sns.countplot(data=EHG_df, y='parent_type', order=EHG_df['parent_type'].value_counts().index)
plt.title('Distribution of Parent Type')
plt.xlabel('Count')
plt.ylabel('Parent Type')
plt.show()

# %%
# 16. Count of Parent Types :

plt.figure(figsize=(10, 6))
EHG_df['parent_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Parent Type')
plt.xlabel('Parent Type')
plt.ylabel('Count')
plt.show()

# %%
# 17. Total Emissions by Parent Entity Type :

emissions_by_parent_type = EHG_df.groupby('parent_type')['total_emissions_MtCO2e'].sum()
plt.figure(figsize=(12, 6))
emissions_by_parent_type.plot(kind='bar')
plt.title('Total Emissions by Parent Entity Type')
plt.xlabel('Parent Entity Type')
plt.ylabel('Total Emissions (MtCO2e)')
plt.show()

# %%
# 18. Distribution of Reporting Entities :

plt.figure(figsize=(10, 6))
sns.countplot(data=EHG_df, y='reporting_entity', order=EHG_df['reporting_entity'].value_counts().index)
plt.title('Distribution of Reporting Entity')
plt.xlabel('Count')
plt.ylabel('Reporting Entity')
plt.show()

# %%
# 19. Count of Reporting Entities :

plt.figure(figsize=(10, 6))
EHG_df['reporting_entity'].value_counts().plot(kind='barh')
plt.title('Distribution of Reporting Entity')
plt.xlabel('Count')
plt.ylabel('Reporting Entity')
plt.show()

# %%
# 20. Distribution of Commodity Types :

plt.figure(figsize=(10, 6))
sns.countplot(data=EHG_df, y='commodity', order=EHG_df['commodity'].value_counts().index)
plt.title('Distribution of Commodity')
plt.xlabel('Count')
plt.ylabel('Commodity')
plt.show()

# %%
# 21. Count of Each Commodity : 

plt.figure(figsize=(10, 6))
EHG_df['commodity'].value_counts().plot(kind='barh')
plt.title('Distribution of Commodity')
plt.xlabel('Count')
plt.ylabel('Commodity')
plt.show()

# %%
# 22. Distribution of Production Units :

plt.figure(figsize=(10, 6))
sns.countplot(data=EHG_df, y='production_unit', order=EHG_df['production_unit'].value_counts().index)
plt.title('Distribution of Production Unit')
plt.xlabel('Count')
plt.ylabel('Production Unit')
plt.show()

# %%
# 23. Proportion of Production Unit Distribution :

plt.figure(figsize=(10, 6))
EHG_df['production_unit'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Production Unit')
plt.ylabel('')
plt.show()

# %%
# 24. Average Total Emissions by Year :

emissions_by_year = EHG_df.groupby('year')['total_emissions_MtCO2e'].mean()
plt.figure(figsize=(12, 6))
emissions_by_year.plot(kind='bar')
plt.title('Average Total Emissions by Year')
plt.xlabel('Year')
plt.ylabel('Average Total Emissions (MtCO2e)')
plt.show()

# %%
# 25. Distribution of Numerical Features in CO2 Emission Dataset :

numerical_columns = EHG_df.select_dtypes(include=[np.number]).columns
EHG_df[numerical_columns].hist(figsize=(15, 10), bins=20)
plt.suptitle('Distribution of Numerical Features in CO2 Emission Dataset', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to make room for the title
plt.show()

# %%
# 26. Distribution of Production Values :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['production_value'], kde=True)
plt.title('Distribution of Production Value')
plt.xlabel('Production Value')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 27. Distribution of Product Emissions (MtCO2) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['product_emissions_MtCO2'], kde=True)
plt.title('Distribution of Product Emissions (MtCO2)')
plt.xlabel('Product Emissions (MtCO2)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 28. Distribution of Flaring Emissions (MtCO2) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['flaring_emissions_MtCO2'], kde=True)
plt.title('Distribution of Flaring Emissions (MtCO2)')
plt.xlabel('Flaring Emissions (MtCO2)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 29. Distribution of Venting Emissions (MtCO2) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['venting_emissions_MtCO2'], kde=True)
plt.title('Distribution of Venting Emissions (MtCO2)')
plt.xlabel('Venting Emissions (MtCO2)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 30. Distribution of Own Fuel Use Emissions (MtCO2) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['own_fuel_use_emissions_MtCO2'], kde=True)
plt.title('Distribution of Own Fuel Use Emissions (MtCO2)')
plt.xlabel('Own Fuel Use Emissions (MtCO2)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 31. Distribution of Fugitive Methane Emissions (MtCO2e) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['fugitive_methane_emissions_MtCO2e'], kde=True)
plt.title('Distribution of Fugitive Methane Emissions (MtCO2e)')
plt.xlabel('Fugitive Methane Emissions (MtCO2e)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 32. Distribution of Fugitive Methane Emissions (MtCH4) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['fugitive_methane_emissions_MtCH4'], kde=True)
plt.title('Distribution of Fugitive Methane Emissions (MtCH4)')
plt.xlabel('Fugitive Methane Emissions (MtCH4)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 33. Distribution of Total Operational Emissions (MtCO2e) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['total_operational_emissions_MtCO2e'], kde=True)
plt.title('Distribution of Total Operational Emissions (MtCO2e)')
plt.xlabel('Total Operational Emissions (MtCO2e)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 34. Distribution of Total CO2 Emissions (MtCO2e) :

plt.figure(figsize=(10, 6))
sns.histplot(EHG_df['total_emissions_MtCO2e'], kde=True)
plt.title('Distribution of Total Emissions (MtCO2e)')
plt.xlabel('Total Emissions (MtCO2e)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\viraj\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
